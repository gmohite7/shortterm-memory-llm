# %%
print('hello world')
# Out:
# hello world

# %%
print('india','pakistan','bangladesh',sep='/')
# Out:
# india/pakistan/bangladesh

# %%
print('hello',end=' ')
print('world')
# Out:
# hellp world

# %%
#data types int, float, str, bool,list,tuples,set,dictionary
#python is case sensitive
for i in range(1,11):
    print(i)

# %%
#built in funcitions
# abs,pow,min,max,sum,len,id,type

# %%
s = 'Hello'
print(s.lower())
# Out:
# hello

# %%
L = [1,2,3,4,5]

L1 = [ i**2 for i in L if i%2 != 0]
print(L1)
# Out:
# [1, 9, 25]

# %%
L1 = [1,2,3]
L2 = [4,5,6,7,8,9]

L3 = zip(L1,L2)
print(list(L3))
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
D = {'name':'Girish Mohite','age':'50','occupation':'IT'}

for k,v in D.items():
    print(k,v)
# Out:
# name Girish Mohite
# age 50
# occupation IT

# %%
D2 = {item:item**2 for item in range(1,11)}
D2
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
S1 = {1,2,3,4,5}
S2 = {4,5,6,7,8}

#union
print(S1|S2)
